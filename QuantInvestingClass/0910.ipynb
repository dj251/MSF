# %%
import pandas as pd
import numpy as np

# %%
ff =  pd.read_csv('FamaFrenchMonthly.csv', parse_dates=['Date'])
ff.describe()
# Out:
# C:\Users\YOGA\AppData\Local\Temp\ipykernel_22688\768175498.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   ff =  pd.read_csv('FamaFrenchMonthly.csv', parse_dates=['Date'])
#             Mkt-RF          SMB          HML           RF
# count  1188.000000  1188.000000  1188.000000  1188.000000
# mean      0.687702     0.164335     0.344722     0.269697
# std       5.319770     3.157440     3.557999     0.249457
# min     -28.740000   -17.410000   -13.830000    -0.060000
# 25%      -2.015000    -1.630000    -1.440000     0.030000
# 50%       1.075000     0.060000     0.140000     0.230000
# 75%       3.660000     1.732500     1.752500     0.420000
# max      38.810000    35.960000    35.520000     1.350000

# %%
ff_1970 = ff.loc[ff['Date'] >= '1970']
ff_1970
# Out:
#         Date  Mkt-RF   SMB   HML    RF
# 522   197001   -8.10  2.91  3.17  0.60
# 523   197002    5.14 -2.39  3.69  0.62
# 524   197003   -1.06 -2.31  4.08  0.57
# 525   197004  -10.99 -6.14  6.14  0.50
# 526   197005   -6.90 -4.61  3.32  0.53
# ...      ...     ...   ...   ...   ...
# 1183  202502   -2.44 -5.79  4.91  0.33
# 1184  202503   -6.39 -2.76  2.90  0.34
# 1185  202504   -0.84 -0.59 -3.40  0.35
# 1186  202505    6.06  0.70 -2.88  0.38
# 1187  202506    4.86  0.83 -1.60  0.34
#
# [666 rows x 5 columns]
